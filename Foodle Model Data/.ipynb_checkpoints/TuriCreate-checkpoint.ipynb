# %% [markdown]
# # Training the hand gestures model with Turi Create
#
# On the small dataset this model gets 100% training accuracy, 80% test set accuracy (3 out of 15 images wrong).

# %%
import turicreate as tc

# %matplotlib inline
import matplotlib.pyplot as plt

import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
tc.__version__, tc.version_info.build_number
# Out:
# ('6.4.1', '154518')

# %% [markdown]
# ## Load the training set

# %%
train_data = tc.image_analysis.load_images("/Users/admin/Desktop/CoreML/Foodle/Dataset/train", with_path=True)

# %%
train_data["label"] = train_data["path"].apply(lambda path: os.path.basename(os.path.split(path)[0]))

# %%
train_data.head()
# Out:
# Columns:
# 	path	str
# 	image	Image
# 	label	str
#
# Rows: 10
#
# Data:
# +-------------------------------+------------------------+-------+
# |              path             |         image          | label |
# +-------------------------------+------------------------+-------+
# | /Users/admin/Desktop/Datas... | Height: 224 Width: 224 |   🍅   |
# | /Users/admin/Desktop/Datas... | Height: 224 Width: 224 |   🍅   |
# | /Users/admin/Desktop/Datas... | Height: 224 Width: 224 |   🍅   |
# | /Users/admin/Desktop/Datas... | Height: 224 Width: 224 |   🍅   |
# | /Users/admin/Desktop/Datas... | Height: 224 Width: 224 |   🍅   |
# | /Users/admin/Desktop/Datas... | Height: 224 Width: 224 |   🍅   |
# | /Users/admin/Desktop/Datas... | Height: 224 Width: 224 |   🍅   |
# | /Users/admin/Desktop/Datas... | Height: 224 Width: 224 |   🍅   |
# | /Users/admin/Desktop/Datas... | Height: 224 Width: 224 |   🍅   |
# | /Users/admin/Desktop/Datas... | Height: 224 Width: 224 |   🍅   |
# +-------------------------------+------------------------+-------+
# [10 rows x 3 columns]

# %%
len(train_data)
# Out:
# 30

# %%
train_data["label"].summary()
# Out:
# +------------------+-------+----------+
# |       item       | value | is exact |
# +------------------+-------+----------+
# |      Length      |   30  |   Yes    |
# | # Missing Values |   0   |   Yes    |
# | # unique values  |   3   |    No    |
# +------------------+-------+----------+
#
# Most frequent items:
# +-------+-------+
# | value | count |
# +-------+-------+
# |   🍅   |   10  |
# |   🍌   |   10  |
# |   🥔   |   10  |
# +-------+-------+

# %% [markdown]
# ## Load the test set

# %%
test_data = tc.image_analysis.load_images("/Users/admin/Desktop/CoreML/Foodle/Dataset/test", with_path=True)
test_data["label"] = test_data["path"].apply(lambda path: os.path.basename(os.path.split(path)[0]))

# %%
test_data["label"].summary()
# Out:
# +------------------+-------+----------+
# |       item       | value | is exact |
# +------------------+-------+----------+
# |      Length      |   15  |   Yes    |
# | # Missing Values |   0   |   Yes    |
# | # unique values  |   3   |    No    |
# +------------------+-------+----------+
#
# Most frequent items:
# +-------+-------+
# | value | count |
# +-------+-------+
# |   🍅   |   5   |
# |   🍌   |   5   |
# |   🥔   |   5   |
# +-------+-------+

# %% [markdown]
# ## Explore the training data

# %%
# Explore interactively -- this is only supported on macOS.
train_data.explore()
# Out:
# <html lang="en">                                                     <head>                                                               <style>                                                              .sframe {                                                            font-size: 12px;                                                   font-family: HelveticaNeue;                                        border: 1px solid silver;                                        }                                                                  .sframe thead th {                                                   background: #F7F7F7;                                               font-family: HelveticaNeue-Medium;                                 font-size: 14px;                                                   line-height: 16.8px;                                               padding-top: 16px;                                                 padding-bottom: 16px;                                              padding-left: 10px;                                                padding-right: 38px;                                               border-top: 1px solid #E9E9E9;                                     border-bottom: 1px solid #E9E9E9;                                  white-space: nowrap;                                               overflow: hidden;                                                  text-overflow:ellipsis;                                            text-align:center;                                                 font-weight:normal;                                              }                                                                  .sframe tbody th {                                                   background: #FFFFFF;                                               text-align:left;                                                   font-weight:normal;                                                border-right: 1px solid #E9E9E9;                                 }                                                                  .sframe td {                                                         background: #FFFFFF;                                               padding-left: 10px;                                                padding-right: 38px;                                               padding-top: 14px;                                                 padding-bottom: 14px;                                              border-bottom: 1px solid #E9E9E9;                                  max-height: 0px;                                                   transition: max-height 5s ease-out;                                vertical-align: middle;                                            font-family: HelveticaNeue;                                        font-size: 12px;                                                   line-height: 16.8px;                                               background: #FFFFFF;                                             }                                                                  .sframe tr {                                                         padding-left: 10px;                                                padding-right: 38px;                                               padding-top: 14px;                                                 padding-bottom: 14px;                                              border-bottom: 1px solid #E9E9E9;                                  max-height: 0px;                                                   transition: max-height 5s ease-out;                                vertical-align: middle;                                            font-family: HelveticaNeue;                                        font-size: 12px;                                                   line-height: 16.8px;                                               background: #FFFFFF;                                             }                                         ...
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>path</th>
#       <th>image</th>
#       <th>label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>/Users/admin/Desktop/Dataset/train/🍅/07E9762F-F528-492A-B6BF-72E8FBD225B3.jpg</td>
#       <td><img src="data:image/png;base64,..."/></td>
#       <td>🍅</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>/Users/admin/Desktop/Dataset/train/🍅/2DBC4403-2549-43BF-A3B4-871557152638.jpg</td>
#       <td><img src="data:image/png;base64,..."/></td>
#       <td>🍅</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>/Users/admin/Desktop/Dataset/train/🍅/48D7289A-4724-4AAB-9B53-E0C0246AF281.jpg</td>
#       <td><img src="data:image/png;base64,..."/></td>
#       <td>🍅</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>/Users/admin/Desktop/Dataset/train/🍅/4F54FB78-EAA2-403A-84DF-3567785FCBE8.jpg</td>
#       <td><img src="data:image/png;base64,..."/></td>
#       <td>🍅</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>/Users/admin/Desktop/Dataset/train/🍅/765B63CA-F3B9-4C96-9A4B-095CEFFF03FD.jpg</td>
#       <td><img src="data:image/png;base64,..."/></td>
#       <td>🍅</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>/Users/admin/Desktop/Dataset/train/🍅/85D131B4-B828-4724-9FB9-82A2623C6EBE.jpg</td>
#       <td><img src="data:image/png;base64,..."/></td>
#       <td>🍅</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>/Users/admin/Desktop/Dataset/train/🍅/8FDEEF3B-8679-40A2-9671-51B668A90573.jpg</td>
#       <td><img src="data:image/png;base64,..."/></td>
#       <td>🍅</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>/Users/admin/Desktop/Dataset/train/🍅/AF3D0888-14E3-4717-B2DF-9D47C651C54A.jpg</td>
#       <td><img src="data:image/png;base64,..."/></td>
#       <td>🍅</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>/Users/admin/Desktop/Dataset/train/🍅/E42439A2-BF2D-4E36-8BEE-D96BE2D9CDCA.jpg</td>
#       <td><img src="data:image/png;base64,..."/></td>
#       <td>🍅</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>/Users/admin/Desktop/Dataset/train/🍅/FF94A237-E25E-4D0D-9A5B-1091A4315F97.jpg</td>
#       <td><img src="data:image/png;base64,..."/></td>
#       <td>🍅</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>/Users/admin/Desktop/Dataset/train/🍌/041BBBC6-1FAD-4AB8-B47B-24E4AB97F8DD.jpg</td>
#       <td><img src="data:image/png;base64,..."/></td>
#       <td>🍌</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>/Users/admin/Desktop/Dataset/train/🍌/3579CC88-630D-4D7F-A9A3-70F72BA7D2C0.jpg</td>
#       <td><img src="data:image/png;base64,..."/></td>
#       <td>🍌</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>/Users/admin/Desktop/Dataset/train/🍌/43F4E5C4-61AA-4C30-A3BD-231B8D107497.jpg</td>
#       <td><img src="data:image/png;base64,..."/></td>
#       <td>🍌</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>/Users/admin/Desktop/Dataset/train/🍌/6C4F53B8-1122-4779-856D-4AC6A8A508ED.jpg</td>
#       <td><img src="data:image/png;base64,..."/></td>
#       <td>🍌</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>/Users/admin/Desktop/Dataset/train/🍌/84A3D517-ECDC-439E-BEF8-37EC5DB9A9B4.jpg</td>
#       <td><img src="data:image/png;base64,..."/></td>
#       <td>🍌</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>/Users/admin/Desktop/Dataset/train/🍌/97503803-F379-4F13-A492-906B7039E9B5.jpg</td>
#       <td><img src="data:image/png;base64,..."/></td>
#       <td>🍌</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>/Users/admin/Desktop/Dataset/train/🍌/9E0EFACC-8F34-4EF3-893D-555F8B46EF0D.jp

# %% [markdown]
# Look at an image:

# %%
img = train_data[7]["image"]
img, type(img), type(img.pixel_data), img.pixel_data.dtype
# Out:
# (Height: 224px
#  Width: 224px
#  Channels: 3,
#  turicreate.data_structures.image.Image,
#  numpy.ndarray,
#  dtype('uint8'))

# %%
plt.imshow(img.pixel_data)

# %% [markdown]
# ## Train the model

# %%
model_type = "squeezenet_v1.1"

# %%
# %time model = tc.image_classifier.create(train_data, target="label", model=model_type, \
                                         verbose=True, max_iterations=100)
# Out:
# Using GPU (Apple M1) to extract features.
# Analyzing and extracting image features.
# +------------------+--------------+------------------+
# | Images Processed | Elapsed Time | Percent Complete |
# +------------------+--------------+------------------+
# | 30               | 117.124ms    | 100%             |
# +------------------+--------------+------------------+
# Logistic regression:
# --------------------------------------------------------
# Number of examples          : 30
# Number of classes           : 3
# Number of feature columns   : 1
# Number of unpacked features : 1000
# Number of coefficients      : 2002
# Starting L-BFGS
# --------------------------------------------------------
# +-----------+----------+-----------+--------------+-------------------+
# | Iteration | Passes   | Step size | Elapsed Time | Training Accuracy |
# +-----------+----------+-----------+--------------+-------------------+
# | 0         | 5        | 0.031174  | 0.043440     | 0.333333          |
# | 1         | 9        | 0.654653  | 0.079478     | 0.500000          |
# | 2         | 10       | 0.818317  | 0.092509     | 0.533333          |
# | 3         | 11       | 1.000000  | 0.107241     | 0.466667          |
# | 4         | 12       | 1.000000  | 0.121619     | 0.633333          |
# | 9         | 21       | 1.000000  | 0.216149     | 1.000000          |
# | 28        | 54       | 1.413051  | 0.578288     | 1.000000          |
# +-----------+----------+-----------+--------------+-------------------+
# CPU times: user 2.75 s, sys: 97 ms, total: 2.85 s
# Wall time: 1.83 s

# %%
model.summary()
# Out:
# Class                                    : ImageClassifier
#
# Schema
# ------
# Number of classes                        : 3
# Number of feature columns                : 1
# Input image shape                        : (3, 227, 227)
#
# Training summary
# ----------------
# Number of examples                       : 30
# Training loss                            : 0.0787
# Training time (sec)                      : 1.833

# %%
model.classifier
# Out:
# Class                          : LogisticClassifier
#
# Schema
# ------
# Number of coefficients         : 2002
# Number of examples             : 30
# Number of classes              : 3
# Number of feature columns      : 1
# Number of unpacked features    : 1000
#
# Hyperparameters
# ---------------
# L1 penalty                     : 0.0
# L2 penalty                     : 0.01
#
# Training Summary
# ----------------
# Solver                         : lbfgs
# Solver iterations              : 28
# Solver status                  : SUCCESS: Optimal solution found.
# Training time (sec)            : 0.3872
#
# Settings
# --------
# Log-likelihood                 : 0.0787
#
# Highest Positive Coefficients
# -----------------------------
# __image_features__[625]        : 0.1048
# __image_features__[690]        : 0.0759
# __image_features__[814]        : 0.0752
# __image_features__[537]        : 0.0623
# __image_features__[665]        : 0.062
#
# Lowest Negative Coefficients
# ----------------------------
# (intercept)                    : -0.1558
# __image_features__[547]        : -0.1127
# __image_features__[734]        : -0.0692
# __image_features__[625]        : -0.0647
# __image_features__[346]        : -0.064

# %%
model.input_image_shape
# Out:
# (3, 227, 227)

# %%
model.model
# Out:
# 'squeezenet_v1.1'

# %%
model.classes
# Out:
# ['🍅', '🍌', '🥔']

# %% [markdown]
# ## Evaluate the trained model

# %%
metrics = model.evaluate(train_data)
metrics["accuracy"]
# Out:
# Analyzing and extracting image features.
# +------------------+--------------+------------------+
# | Images Processed | Elapsed Time | Percent Complete |
# +------------------+--------------+------------------+
# | 30               | 54.041ms     | 100%             |
# +------------------+--------------+------------------+
# 1.0

# %%
metrics = model.evaluate(test_data)
# Out:
# Analyzing and extracting image features.
# +------------------+--------------+------------------+
# | Images Processed | Elapsed Time | Percent Complete |
# +------------------+--------------+------------------+
# | 15               | 32.885ms     | 100%             |
# +------------------+--------------+------------------+

# %%
for k, v in metrics.items():
    print(k, "\n", v)
# Out:
# accuracy
#  0.8
# f1_score
#  0.7712842712842712
# log_loss
#  2.126302806722627
# precision
#  0.8492063492063493
# recall
#  0.7999999999999999
# auc
#  0.8999999999999999
# roc_curve
#  +-----------+-----+-----+---+----+-------+
# | threshold | fpr | tpr | p | n  | class |
# +-----------+-----+-----+---+----+-------+
# |    0.0    | 1.0 | 1.0 | 5 | 10 |   0   |
# |   0.001   | 0.7 | 1.0 | 5 | 10 |   0   |
# |   0.002   | 0.6 | 1.0 | 5 | 10 |   0   |
# |   0.003   | 0.6 | 1.0 | 5 | 10 |   0   |
# |   0.004   | 0.6 | 1.0 | 5 | 10 |   0   |
# |   0.005   | 0.5 | 1.0 | 5 | 10 |   0   |
# |   0.006   | 0.4 | 1.0 | 5 | 10 |   0   |
# |   0.007   | 0.3 | 1.0 | 5 | 10 |   0   |
# |   0.008   | 0.3 | 1.0 | 5 | 10 |   0   |
# |   0.009   | 0.3 | 1.0 | 5 | 10 |   0   |
# +-----------+-----+-----+---+----+-------+
# [3003 rows x 6 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.
# confusion_matrix
#  +--------------+-----------------+-------+
# | target_label | predicted_label | count |
# +--------------+-----------------+-------+
# |      🍌       |        🍌        |   2   |
# |      🍌       |        🍅        |   1   |
# |      🥔       |        🥔        |   5   |
# |      🍅       |        🍅        |   5   |
# |      🍌       |        🥔        |   2   |
# +--------------+-----------------+-------+
# [5 rows x 3 columns]

# %%
metrics["confusion_matrix"]
# Out:
# Columns:
# 	target_label	str
# 	predicted_label	str
# 	count	int
#
# Rows: 5
#
# Data:
# +--------------+-----------------+-------+
# | target_label | predicted_label | count |
# +--------------+-----------------+-------+
# |      🍌       |        🍌        |   2   |
# |      🍌       |        🍅        |   1   |
# |      🥔       |        🥔        |   5   |
# |      🍅       |        🍅        |   5   |
# |      🍌       |        🥔        |   2   |
# +--------------+-----------------+-------+
# [5 rows x 3 columns]

# %%
predictions = model.predict(test_data)
predictions
# Out:
# dtype: str
# Rows: 15
# ['🍅', '🍅', '🍅', '🍅', '🍅', '🍌', '🥔', '🍌', '🍅', '🥔', '🥔', '🥔', '🥔', '🥔', '🥔']

# %%
plt.imshow(test_data[1]["image"].pixel_data)

# %%
output = model.classify(test_data)
output.print_rows(num_rows=15, num_columns=2)
# Out:
# +-------+--------------------+
# | class |    probability     |
# +-------+--------------------+
# |   🍅   | 0.9904974036622222 |
# |   🍅   | 0.5951321613611443 |
# |   🍅   | 0.9846368619739345 |
# |   🍅   | 0.982433549106279  |
# |   🍅   | 0.8712453629443444 |
# |   🍌   | 0.7092033675723995 |
# |   🥔   | 0.9934986568944417 |
# |   🍌   | 0.9998773042087247 |
# |   🍅   | 0.835142599891105  |
# |   🥔   | 0.9873614704999687 |
# |   🥔   | 0.9948855223119436 |
# |   🥔   | 0.9979449868335889 |
# |   🥔   | 0.9964700981234299 |
# |   🥔   |  0.99993785518871  |
# |   🥔   | 0.9954693991420301 |
# +-------+--------------------+
# [15 rows x 2 columns]

# %%
imgs_with_pred = test_data.add_columns(output)
imgs_with_pred.explore()
# Out:
# <html lang="en">                                                     <head>                                                               <style>                                                              .sframe {                                                            font-size: 12px;                                                   font-family: HelveticaNeue;                                        border: 1px solid silver;                                        }                                                                  .sframe thead th {                                                   background: #F7F7F7;                                               font-family: HelveticaNeue-Medium;                                 font-size: 14px;                                                   line-height: 16.8px;                                               padding-top: 16px;                                                 padding-bottom: 16px;                                              padding-left: 10px;                                                padding-right: 38px;                                               border-top: 1px solid #E9E9E9;                                     border-bottom: 1px solid #E9E9E9;                                  white-space: nowrap;                                               overflow: hidden;                                                  text-overflow:ellipsis;                                            text-align:center;                                                 font-weight:normal;                                              }                                                                  .sframe tbody th {                                                   background: #FFFFFF;                                               text-align:left;                                                   font-weight:normal;                                                border-right: 1px solid #E9E9E9;                                 }                                                                  .sframe td {                                                         background: #FFFFFF;                                               padding-left: 10px;                                                padding-right: 38px;                                               padding-top: 14px;                                                 padding-bottom: 14px;                                              border-bottom: 1px solid #E9E9E9;                                  max-height: 0px;                                                   transition: max-height 5s ease-out;                                vertical-align: middle;                                            font-family: HelveticaNeue;                                        font-size: 12px;                                                   line-height: 16.8px;                                               background: #FFFFFF;                                             }                                                                  .sframe tr {                                                         padding-left: 10px;                                                padding-right: 38px;                                               padding-top: 14px;                                                 padding-bottom: 14px;                                              border-bottom: 1px solid #E9E9E9;                                  max-height: 0px;                                                   transition: max-height 5s ease-out;                                vertical-align: middle;                                            font-family: HelveticaNeue;                                        font-size: 12px;                                                   line-height: 16.8px;                                               background: #FFFFFF;                                             }                                         ...
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>path</th>
#       <th>image</th>
#       <th>label</th>
#       <th>class</th>
#       <th>probability</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>/Users/admin/Desktop/Dataset/test/🍅/BB551DC3-8BCF-44E2-8F13-E307F3B4B54D.jpg</td>
#       <td><img src="data:image/png;base64,..."/></td>
#       <td>🍅</td>
#       <td>🍅</td>
#       <td>0.990497</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>/Users/admin/Desktop/Dataset/test/🍅/CA7291E6-2324-4723-8CC5-85F96B005A34.jpg</td>
#       <td><img src="data:image/png;base64,..."/></td>
#       <td>🍅</td>
#       <td>🍅</td>
#       <td>0.595132</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>/Users/admin/Desktop/Dataset/test/🍅/D109269E-3524-4107-B4E8-87FA268E95C2.jpg</td>
#       <td><img src="data:image/png;base64,..."/></td>
#       <td>🍅</td>
#       <td>🍅</td>
#       <td>0.984637</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>/Users/admin/Desktop/Dataset/test/🍅/E2062F5D-E218-43E6-8FE0-122093F7EF79.jpg</td>
#       <td><img src="data:image/png;base64,..."/></td>
#       <td>🍅</td>
#       <td>🍅</td>
#       <td>0.982434</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>/Users/admin/Desktop/Dataset/test/🍅/ED30CAFB-8FC5-473F-A0CA-D0CD10B0364C.jpg</td>
#       <td><img src="data:image/png;base64,..."/></td>
#       <td>🍅</td>
#       <td>🍅</td>
#       <td>0.871245</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>/Users/admin/Desktop/Dataset/test/🍌/0B9ED0A1-A3A6-47E8-A63E-BD797D08AD2C.jpg</td>
#       <td><img src="data:image/png;base64,..."/></td>
#       <td>🍌</td>
#       <td>🍌</td>
#       <td>0.709203</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>/Users/admin/Desktop/Dataset/test/🍌/31A86EB7-67DD-4865-8EA2-902D4F2CEE4A.jpg</td>
#       <td><img src="data:image/png;base64,..."/></td>
#       <td>🍌</td>
#       <td>🥔</td>
#       <td>0.993499</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>/Users/admin/Desktop/Dataset/test/🍌/D12017BC-F491-4B84-9FFE-FAE7866456F7.jpg</td>
#       <td><img src="data:image/png;base64,..."/></td>
#       <td>🍌</td>
#       <td>🍌</td>
#       <td>0.999877</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>/Users/admin/Desktop/Dataset/test/🍌/E5EFE292-0033-41A2-9853-D35B4FC4132A.jpg</td>
#       <td><img src="data:image/png;base64,..."/></td>
#       <td>🍌</td>
#       <td>🍅</td>
#       <td>0.835143</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>/Users/admin/Desktop/Dataset/test/🍌/EF9B5265-12D9-408B-9B4E-0892C5F26713.jpg</td>
#       <td><img src="data:image/png;base64,..."/></td>
#       <td>🍌</td>
#       <td>🥔</td>
#       <td>0.987361</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>/Users/admin/Desktop/Dataset/test/🥔/5C49CFF8-BA23-49FF-8C99-B4EFE26B63DA.jpg</td>
#       <td><img src="data:image/png;base64,..."/></td>
#       <td>🥔</td>
#       <td>🥔</td>
#       <td>0.994886</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>/Users/admin/Desktop/Dataset/test/🥔/69E216C3-745F-4143-BD92-87C872E3C828.jpg</td>
#       <td><img src="data:image/png;base64,..."/></td>
#       <td>🥔</td>
#       <td>🥔</td>
#       <td>0.997945</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>/Users/admin/Desktop/Dataset/test/🥔/A19E5846-E739-4D56-8BFA-EBE518CE4BDB.jpg</td>
#       <td><img src="data:image/png;base64,..."/></td>
#       <td>🥔</td>
#       <td>🥔</td>
#       <td>0.996470</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>/Users/admin/Desktop/Dataset/test/🥔/D1E0FD26-7C16-4516-9A72-9543C4F9C5A2.jpg</td>
#       <td><img src="data:imag

# %% [markdown]
# ## Export to Core ML

# %%
model.export_coreml("/Users/admin/Desktop/CoreML/Foodle/VegetablesTuri.mlmodel")
